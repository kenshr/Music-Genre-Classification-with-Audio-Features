# %%
# imports
import numpy as np
import pandas as pd

from tqdm import tqdm

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp_cid = 'Insert cid here'
sp_secret = 'Insert secret here'
client_credentials_manager = SpotifyClientCredentials(client_id=sp_cid, client_secret=sp_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df = pd.read_csv('../data/track_dataset_no_audio_features.csv', index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113000 entries, 0 to 112999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   track_name   113000 non-null  object
#  1   artist_name  113000 non-null  object
#  2   album_name   113000 non-null  object
#  3   genre        113000 non-null  object
#  4   duration_ms  113000 non-null  int64
#  5   popularity   113000 non-null  int64
#  6   explicit     113000 non-null  bool
#  7   track_id     113000 non-null  object
#  8   artist_id    113000 non-null  object
# dtypes: bool(1), int64(2), object(6)
# memory usage: 7.9+ MB

# %%
grouped = df.groupby(['artist_name','track_name'], as_index=True).size()
# number of duplicate tracks
len(grouped[grouped > 1])
# Out:
# 19540

# %%
# number of songs after removal of dupes
len(grouped)
# Out:
# 77629

# %%
df['genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
#        'new-age', 'opera', 'pagode', 'party', 'piano', 'pop', 'pop-film',
#        'power-pop', 'progressive-house', 'psych-rock', 'punk',
#        'punk-rock', 'r-n-b', 'reggae', 'reggaeton', 'rock', 'rock-n-roll',
#        'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
#        'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
#        'soul', 'spanish', 'swedish', 'synth-pop', 'tango', 'techno',
#        'trance', 'trip-hop', 'turkish', 'world-music'], dtype=object)

# %%
final_selection = ['acoustic','alternative','ambient','classical','country',
                   'disco','edm','funk','gospel','heavy-metal','hip-hop','jazz','k-pop','latin','opera','r-n-b','rock',
                   'reggae','techno','world-music']
test_df = df[df['genre'].isin(final_selection)]

# %%
print(len(test_df))

tgrouped = test_df.groupby(['artist_name','track_name'], as_index=True).size()
len(tgrouped[tgrouped > 1])
# Out:
# 20000
# 2277

# %%
new = test_df.drop_duplicates(subset=['track_name','artist_name'])

# %%
len(new)
# Out:
# 16025

# %%
new.groupby('genre').count()
# Out:
#              track_name  artist_name  album_name  duration_ms  popularity  \
# genre
# acoustic            949          949         949          949         949
# alternative         958          958         958          958         958
# ambient             932          932         932          932         932
# classical           920          920         920          920         920
# country             941          941         941          941         941
# disco               878          878         878          878         878
# edm                 853          853         853          853         853
# funk                598          598         598          598         598
# gospel              930          930         930          930         930
# heavy-metal         957          957         957          957         957
# hip-hop             807          807         807          807         807
# jazz                869          869         869          869         869
# k-pop               922          922         922          922         922
# latin               432          432         432          432         432
# opera               942          942         942          942         942
# r-n-b               834          834         834          834         834
# reggae              101          101         101          101         101
# rock                510          510         510          510         510
# techno              915          915         915          915         915
# world-music         777          777         777          777         777
#
#              explicit  track_id  artist_id
# genre
# acoustic          949       949        949
# alternative       958       958        958
# ambient           932       932        932
# classical         920       920        920
# country           941       941        941
# disco             878       878        878
# edm               853       853        853
# funk              598       598        598
# gospel            930       930        930
# heavy-metal       957       957        957
# hip-hop           807       807        807
# jazz              869       869        869
# k-pop             922       922        922
# latin             432       432        432
# opera             942       942        942
# r-n-b             834       834        834
# reggae            101       101        101
# rock              510       510        510
# techno            915       915        915
# world-music       777       777        777

# %%
# Join all genres
multi_genre_df = df.groupby(['track_name','artist_name','album_name','duration_ms','popularity','explicit','track_id','artist_id'])['genre'].apply(', '.join).reset_index()

# %%
multi_genre_df
# Out:
#                                               track_name  \
# 0                                                   "45"
# 1                                       "A Lovely Night"
# 2                                    "A" You're Adorable
# 3      "Befiehl du deine Wege" (Herzlich tut mich ver...
# 4                                      "C" is for Cookie
# ...                                                  ...
# 85196                             예뻤어 You Were Beautiful
# 85197                                     오랜 소원 It's You
# 85198                                         유로파 Europa
# 85199                                유리아이 (Lost In Love)
# 85200                                    하드캐리 Hard Carry
#
#                  artist_name  \
# 0        The Gaslight Anthem
# 1                Laura Osnes
# 2               Brian Hyland
# 3      Johann Sebastian Bach
# 4             Cookie Monster
# ...                      ...
# 85196                   DAY6
# 85197      Girls' Generation
# 85198      Girls' Generation
# 85199      Girls' Generation
# 85200                   GOT7
#
#                                               album_name  duration_ms  \
# 0                                            Handwritten       202493
# 1      Rodgers + Hammerstein's Cinderella (Original B...       151466
# 2                                      The Bashful Blond       151680
# 3                                 Classical Spring: Bach       131569
# 4             Sesame Street: Platinum All-Time Favorites        89204
# ...                                                  ...          ...
# 85196                                            SUNRISE       283160
# 85197                      Holiday Night - The 6th Album       232615
# 85198                       Mr. Mr. - The 4th Mini Album       202026
# 85199                        I GOT A BOY - The 4th Album       239903
# 85200                            FLIGHT LOG : TURBULENCE       193578
#
#        popularity  explicit                track_id               artist_id  \
# 0              52     False  25Sd73fleKUVPNqITPZkn1  7If8DXZN7mlGdQkLE2FaMo
# 1              35     False  7ygnMprPnDekUSeduRDhDt  2TkSDFFCkyiMrHyL1a5BbF
# 2              43     False  6CvreUbryAmXAUo35wuCQJ  6YROFUbu5zRCHi2xkir5pk
# 3               0     False  4e21qOZFA4BUDeaMVVYc6g  5aIqB5nVVvmFsvSdExz408
# 4              53     False  6EVN97RIyZBCegsYyEnkMv  0KUfoAHP20vQHuDhiEAa8r
# ...           ...       ...                     ...                     ...
# 85196          68     False  71WZ7yFuwxmQz5jJUpvkGv  5TnQc2N1iKlFjYD7CPGvFc
# 85197          32     False  2o0tBYtr3tBBqesoZzHklI  0Sadg1vgvaPqGTOjxu0N6c
# 85198          38     False  13raMIk3oXkgjP2hAvVCu2  0Sadg1vgvaPqGTOjxu0N6c
# 85199          37     False  3ds1h65uxnS3zVmaVLGTHQ  0Sadg1vgvaPqGTOjxu0N6c
# 85200          60     False  1xzCUpXSMnAbckUXDwBTlW  6nfDaffa50mKtEOwR8g4df
#
#                                                    genre
# 0      hard-rock, hardcore, j-rock, punk, punk-rock, ska
# 1                                             show-tunes
# 2                                rock-n-roll, rockabilly
# 3                                                 german
# 4                                               children
# ...                                                  ...
# 85196                                              k-pop
# 85197                                             j-idol
# 85198                                             j-idol
# 85199                                             j-idol
# 85200                                              k-pop
#
# [85201 rows x 9 columns]

# %%
# Join all duplicates of songs and consolidate the genres for each song if multiple 
multi_genre_df['genre'] = multi_genre_df.genre.map(lambda x: list(set(x.split(', '))))

# %%
multi_genre_df
# Out:
#                                               track_name  \
# 0                                                   "45"
# 1                                       "A Lovely Night"
# 2                                    "A" You're Adorable
# 3      "Befiehl du deine Wege" (Herzlich tut mich ver...
# 4                                      "C" is for Cookie
# ...                                                  ...
# 85196                             예뻤어 You Were Beautiful
# 85197                                     오랜 소원 It's You
# 85198                                         유로파 Europa
# 85199                                유리아이 (Lost In Love)
# 85200                                    하드캐리 Hard Carry
#
#                  artist_name  \
# 0        The Gaslight Anthem
# 1                Laura Osnes
# 2               Brian Hyland
# 3      Johann Sebastian Bach
# 4             Cookie Monster
# ...                      ...
# 85196                   DAY6
# 85197      Girls' Generation
# 85198      Girls' Generation
# 85199      Girls' Generation
# 85200                   GOT7
#
#                                               album_name  duration_ms  \
# 0                                            Handwritten       202493
# 1      Rodgers + Hammerstein's Cinderella (Original B...       151466
# 2                                      The Bashful Blond       151680
# 3                                 Classical Spring: Bach       131569
# 4             Sesame Street: Platinum All-Time Favorites        89204
# ...                                                  ...          ...
# 85196                                            SUNRISE       283160
# 85197                      Holiday Night - The 6th Album       232615
# 85198                       Mr. Mr. - The 4th Mini Album       202026
# 85199                        I GOT A BOY - The 4th Album       239903
# 85200                            FLIGHT LOG : TURBULENCE       193578
#
#        popularity  explicit                track_id               artist_id  \
# 0              52     False  25Sd73fleKUVPNqITPZkn1  7If8DXZN7mlGdQkLE2FaMo
# 1              35     False  7ygnMprPnDekUSeduRDhDt  2TkSDFFCkyiMrHyL1a5BbF
# 2              43     False  6CvreUbryAmXAUo35wuCQJ  6YROFUbu5zRCHi2xkir5pk
# 3               0     False  4e21qOZFA4BUDeaMVVYc6g  5aIqB5nVVvmFsvSdExz408
# 4              53     False  6EVN97RIyZBCegsYyEnkMv  0KUfoAHP20vQHuDhiEAa8r
# ...           ...       ...                     ...                     ...
# 85196          68     False  71WZ7yFuwxmQz5jJUpvkGv  5TnQc2N1iKlFjYD7CPGvFc
# 85197          32     False  2o0tBYtr3tBBqesoZzHklI  0Sadg1vgvaPqGTOjxu0N6c
# 85198          38     False  13raMIk3oXkgjP2hAvVCu2  0Sadg1vgvaPqGTOjxu0N6c
# 85199          37     False  3ds1h65uxnS3zVmaVLGTHQ  0Sadg1vgvaPqGTOjxu0N6c
# 85200          60     False  1xzCUpXSMnAbckUXDwBTlW  6nfDaffa50mKtEOwR8g4df
#
#                                                    genre
# 0      [hardcore, punk-rock, j-rock, hard-rock, ska, ...
# 1                                           [show-tunes]
# 2                              [rockabilly, rock-n-roll]
# 3                                               [german]
# 4                                             [children]
# ...                                                  ...
# 85196                                            [k-pop]
# 85197                                           [j-idol]
# 85198                                           [j-idol]
# 85199                                           [j-idol]
# 85200                                            [k-pop]
#
# [85201 rows x 9 columns]

# %%
# We still have dupes!!!
dupes = multi_genre_df.groupby(['artist_name','track_name'], as_index=True).size()
len(dupes[dupes > 1])
# Out:
# 5191

# %%
# Remove dupes that didn't get consolidated because of minor differences (i.e. same song, different album)
multi_genre_df['num_genres'] = multi_genre_df['genre'].str.len()
sorted_multi = multi_genre_df.sort_values(by='num_genres',ascending=False).drop(columns='num_genres').reset_index(drop=True)
sorted_multi.drop_duplicates(subset=['track_name','artist_name'],inplace=True)

# %%
sorted_multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77629 entries, 0 to 85200
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   track_name   77629 non-null  object
#  1   artist_name  77629 non-null  object
#  2   album_name   77629 non-null  object
#  3   duration_ms  77629 non-null  int64
#  4   popularity   77629 non-null  int64
#  5   explicit     77629 non-null  bool
#  6   track_id     77629 non-null  object
#  7   artist_id    77629 non-null  object
#  8   genre        77629 non-null  object
# dtypes: bool(1), int64(2), object(6)
# memory usage: 5.4+ MB

# %%
# No more dupes
dupes = sorted_multi.groupby(['artist_name','track_name'], as_index=True).size()
len(dupes[dupes > 1])
# Out:
# 0

# %%
def audio_feature_collector(track_id_lst):
    """
    Takes a list of track id's and returns a dataframe filled
    with the audio features for the provided songs.

    Parameters:
    -----------
    track_id_lst: list of track id's

    Output:
    -------
    Returns a dataframe object
    """
    audio_features = []
    batchsize = 100

    # Iterate over 100 song batches (due to API limit per request)
    for i in tqdm(range(0,len(track_id_lst),batchsize)):
        batch = track_id_lst[i:i+batchsize]
        # Collect features for 100 tracks
        feature_results = sp.audio_features(batch)
        # Store individual track info in list
        for track in feature_results:
            if track is not None:
                audio_features.append(track)

    df = pd.DataFrame.from_dict(data=audio_features,orient='columns')
    # Rename column to match column name from song dataframe for merge
    return df.rename(columns={'id':'track_id'})

# %%
af = audio_feature_collector(sorted_multi.track_id.to_list())
# Out:
# 100%|██████████| 777/777 [06:41<00:00,  1.93it/s]

# %%
af
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.701   0.815    0    -5.995     1       0.0381      0.017400
# 1             0.509   0.646   11    -6.285     0       0.0365      0.000280
# 2             0.338   0.819    3    -5.666     1       0.0736      0.023400
# 3             0.325   0.867    4    -5.530     1       0.0809      0.005480
# 4             0.482   0.833    5    -5.611     1       0.0449      0.000346
# ...             ...     ...  ...       ...   ...          ...           ...
# 77624         0.693   0.708    0    -7.816     1       0.0310      0.309000
# 77625         0.774   0.776    6    -5.331     1       0.3040      0.178000
# 77626         0.269   0.942    2    -4.604     1       0.0575      0.000173
# 77627         0.829   0.727    7    -8.606     1       0.1650      0.429000
# 77628         0.700   0.873    1    -2.901     1       0.0869      0.014800
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000627    0.0969    0.671  138.142  audio_features
# 1              0.004680    0.0973    0.142  124.014  audio_features
# 2              0.000000    0.1290    0.698  118.905  audio_features
# 3              0.000004    0.1030    0.336  144.866  audio_features
# 4              0.000000    0.3650    0.740  148.039  audio_features
# ...                 ...       ...      ...      ...             ...
# 77624          0.003050    0.0857    0.949  125.315  audio_features
# 77625          0.000000    0.2830    0.654   99.071  audio_features
# 77626          0.000001    0.1610    0.665   88.850  audio_features
# 77627          0.000000    0.0709    0.907  101.644  audio_features
# 77628          0.000000    0.3430    0.612   99.972  audio_features
#
#                      track_id                                   uri  \
# 0      6M6UoxIPn4NOWW0x7JPRfv  spotify:track:6M6UoxIPn4NOWW0x7JPRfv
# 1      72hSmnleYTiiOo23q8ZJIS  spotify:track:72hSmnleYTiiOo23q8ZJIS
# 2      7t19ubLwfZubJh2HpCUTrC  spotify:track:7t19ubLwfZubJh2HpCUTrC
# 3      0Kd1R41kTx9Uzk30yv5PP7  spotify:track:0Kd1R41kTx9Uzk30yv5PP7
# 4      1fBl642IhJOE5U319Gy2Go  spotify:track:1fBl642IhJOE5U319Gy2Go
# ...                       ...                                   ...
# 77624  6c0G8K6G2LlIfJTsRLJjfs  spotify:track:6c0G8K6G2LlIfJTsRLJjfs
# 77625  2Uvwc7D5rhphlzfBDnpYpU  spotify:track:2Uvwc7D5rhphlzfBDnpYpU
# 77626  1tSBySlxQCtYcRXAq0lz7u  spotify:track:1tSBySlxQCtYcRXAq0lz7u
# 77627  6tBzYurAiGkaGopgYPdNo7  spotify:track:6tBzYurAiGkaGopgYPdNo7
# 77628  1xzCUpXSMnAbckUXDwBTlW  spotify:track:1xzCUpXSMnAbckUXDwBTlW
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6M6UoxIPn4NO...
# 1      https://api.spotify.com/v1/tracks/72hSmnleYTii...
# 2      https://api.spotify.com/v1/tracks/7t19ubLwfZub...
# 3      https://api.spotify.com/v1/tracks/0Kd1R41kTx9U...
# 4      https://api.spotify.com/v1/tracks/1fBl642IhJOE...
# ...                                                  ...
# 77624  https://api.spotify.com/v1/tracks/6c0G8K6G2LlI...
# 77625  https://api.spotify.com/v1/tracks/2Uvwc7D5rhph...
# 77626  https://api.spotify.com/v1/tracks/1tSBySlxQCtY...
# 77627  https://api.spotify.com/v1/tracks/6tBzYurAiGka...
# 77628  https://api.spotify.com/v1/tracks/1xzCUpXSMnAb...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6M6U...       279027
# 1      https://api.spotify.com/v1/audio-analysis/72hS...       297460
# 2      https://api.spotify.com/v1/audio-analysis/7t19...       167307
# 3      https://api.spotify.com/v1/audio-analysis/0Kd1...       264677
# 4      https://api.spotify.com/v1/audio-analysis/1fBl...       212293
# ...                                                  ...          ...
# 77624  https://api.spotify.com/v1/audio-analysis/6c0G...       187973
# 77625  https://api.spotify.com/v1/audio-analysis/2Uvw...       311533
# 77626  https://api.spotify.com/v1/audio-analysis/1tSB...       156162
# 77627  https://api.spotify.com/v1/audio-analysis/6tBz...       156360
# 77628  https://api.spotify.com/v1/audio-analysis/1xzC...       193579
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 77624               4
# 77625               4
# 77626               4
# 77627               4
# 77628               4
#
# [77629 rows x 18 columns]

# %%
# Remove unwanted features
af.drop(['type','uri','track_href','analysis_url','duration_ms','time_signature'],axis=1,inplace=True)

# %%
final = pd.merge(sorted_multi,af,how='inner',on='track_id')

# %%
final
# Out:
#                                               track_name  \
# 0                                            Young Folks
# 1                                            Black Sheep
# 2                                          Be Nice To Me
# 3                                     Twin Size Mattress
# 4                                                 Animal
# ...                                                  ...
# 77624                I Love The Nightlife (Disco 'Round)
# 77625  I Love The Dough (feat. Jay-Z & Angela Winbush...
# 77626                                     I Love Seattle
# 77627                                  I Love Rocky Road
# 77628                                    하드캐리 Hard Carry
#
#                 artist_name                                  album_name  \
# 0      Peter Bjorn and John                              Writer's Block
# 1                    Metric                                 Black Sheep
# 2         The Front Bottoms                                        Rose
# 3         The Front Bottoms                           Talon Of The Hawk
# 4                Neon Trees                                      Habits
# ...                     ...                                         ...
# 77624        Alicia Bridges                        I Love The Nightlife
# 77625  The Notorious B.I.G.  Life After Death (2014 Remastered Edition)
# 77626               Tacocat                                   Lost Time
# 77627   "Weird Al" Yankovic                         "Weird Al" Yankovic
# 77628                  GOT7                     FLIGHT LOG : TURBULENCE
#
#        duration_ms  popularity  explicit                track_id  \
# 0           279026          65     False  6M6UoxIPn4NOWW0x7JPRfv
# 1           297459          68     False  72hSmnleYTiiOo23q8ZJIS
# 2           167306          63     False  7t19ubLwfZubJh2HpCUTrC
# 3           264676          65     False  0Kd1R41kTx9Uzk30yv5PP7
# 4           212293          72     False  1fBl642IhJOE5U319Gy2Go
# ...            ...         ...       ...                     ...
# 77624       187973          47     False  6c0G8K6G2LlIfJTsRLJjfs
# 77625       311533          56      True  2Uvwc7D5rhphlzfBDnpYpU
# 77626       156162          35     False  1tSBySlxQCtYcRXAq0lz7u
# 77627       156360          37     False  6tBzYurAiGkaGopgYPdNo7
# 77628       193578          60     False  1xzCUpXSMnAbckUXDwBTlW
#
#                     artist_id  \
# 0      6u11Qbko2N2hP4lTBYjX86
# 1      1rCIEwPp5OnXW0ornlSsRl
# 2      5ictveRyhWRs8Gt8Dvt1hS
# 3      5ictveRyhWRs8Gt8Dvt1hS
# 4      0RpddSzUHfncUWNJXKOsjy
# ...                       ...
# 77624  1UY4oIFpjCKe5qIhKDcloe
# 77625  5me0Irg2ANcsgc93uaYrpb
# 77626  3h0MN1neFknEvlYKxFmSQW
# 77627  1bDWGdIC2hardyt55nlQgG
# 77628  6nfDaffa50mKtEOwR8g4df
#
#                                                    genre  danceability  \
# 0      [swedish, indie-pop, dance, indie, alt-rock, p...         0.701
# 1      [indie-pop, dance, indie, alt-rock, punk-rock,...         0.509
# 2      [j-pop, indie-pop, emo, indie, alt-rock, punk-...         0.338
# 3      [j-pop, indie-pop, emo, indie, alt-rock, punk-...         0.325
# 4      [indie-pop, indie, alt-rock, punk-rock, pop, r...         0.482
# ...                                                  ...           ...
# 77624                                            [disco]         0.693
# 77625                                         [hardcore]         0.774
# 77626                                        [power-pop]         0.269
# 77627                                           [comedy]         0.829
# 77628                                            [k-pop]         0.700
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 0       0.815    0    -5.995     1       0.0381      0.017400
# 1       0.646   11    -6.285     0       0.0365      0.000280
# 2       0.819    3    -5.666     1       0.0736      0.023400
# 3       0.867    4    -5.530     1       0.0809      0.005480
# 4       0.833    5    -5.611     1       0.0449      0.000346
# ...       ...  ...       ...   ...          ...           ...
# 77624   0.708    0    -7.816     1       0.0310      0.309000
# 77625   0.776    6    -5.331     1       0.3040      0.178000
# 77626   0.942    2    -4.604     1       0.0575      0.000173
# 77627   0.727    7    -8.606     1       0.1650      0.429000
# 77628   0.873    1    -2.901     1       0.0869      0.014800
#
#        instrumentalness  liveness  valence    tempo
# 0              0.000627    0.0969    0.671  138.142
# 1              0.004680    0.0973    0.142  124.014
# 2              0.000000    0.1290    0.698  118.905
# 3              0.000004    0.1030    0.336  144.866
# 4              0.000000    0.3650    0.740  148.039
# ...                 ...       ...      ...      ...
# 77624          0.003050    0.0857    0.949  125.315
# 77625          0.000000    0.2830    0.654   99.071
# 77626          0.000001    0.1610    0.665   88.850
# 77627          0.000000    0.0709    0.907  101.644
# 77628          0.000000    0.3430    0.612   99.972
#
# [77629 rows x 20 columns]

# %%
# Replace booleans with integers
final.explicit = df.explicit.astype(int)

# Convert from milliseconds to seconds
final['duration_s'] = np.round(final.duration_ms/1000,0)

# %%
final.to_csv('../data/multi_genre_track_audio_dataset.csv')
